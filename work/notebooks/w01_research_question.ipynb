# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Deeps1970/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# !git clone https://github.com/Deeps1970/flyrank-ml-internship.git
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 119, done.
# remote: Counting objects: 100% (119/119), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 119 (delta 34), reused 94 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (119/119), 1.82 MiB | 15.81 MiB/s, done.
# Resolving deltas: 100% (34/34), done.

# %%
My Lane

Selected Lane
Lane 2: Refresh / Content Opportunity Scoring

Why I Chose This Lane

The reason for choosing the lane of Refresh / Content Opportunity Scoring is that this lane concentrates on the aspects of how to assist the teams in deciding about the pages which will be reviewed first, based on the indicators concerning the engagement and the search signals received. The importance of this lane is in its exact connection with the starter notebooks which provided me with the information concerning the use of machine learning models to improve the process of page prioritization in comparison to the use of traditional rule-based methods.

The lane is also important due to its practical nature, as the content teams usually face problems owing to them having limited time for reviewing thousands of pages. The implementation of the ranking system will allow them to review the pages which will be most likely to be updated.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# Research Question

## Search Question
How do you choose what content pages should be reviewed first based on signals from search and engagement?

## Unit of Analysis
Each content page is represented one time.

## Output
A list of pages ranked by priority for content refresh and reasons given for the ranking.

## Decision
To help SEO or content specialists to understand what pages need to be reviewed first.

## Action
To review the most important pages first and establish if any content changes, updates, optimization, or just monitoring is required.

## Cost of a Wrong Recommendation
Choosing a page that is not really important would cause the team to waste valuable time in the review process. Not choosing an important page would lead to observation opportunities being lost. Thus, recommendations should help in making an independent decision rather than being decision-makers.

## Why Machine Learning Can Help
The rule-based approach is simplistic as it takes into account one or two indicators at most. On the contrary, ML can discover correlations between various observable indicators (for instance, impressions, CTR, engagement, content age, and average position) to perform better at ranking while still allowing people to make the final decision.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv(
    "flyrank-ml-internship/data/raw/content_refresh_anonymized.csv"
)

print("Dataset Shape:", df.shape)
print("Unique Pages:", df["content_id"].nunique())
print("Pages with Declining Trend:", (df["trend_direction"]=="down").sum())
print("Average CTR:", round(df["ctr"].mean(),2))
print("Average Impressions:", round(df["impressions_90d"].mean(),2))
# Out:
# Dataset Shape: (30000, 44)
# Unique Pages: 30000
# Pages with Declining Trend: 16262
# Average CTR: 0.51
# Average Impressions: 5200.37

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# Thoughtful Language
The present project is based on data gathered from observing search and engagement metrics.
The findings may reveal links and trends between observable signals and page performance; however, they cannot indicate that one element causes another.
Similarly, this project does not demonstrate the operation of Google's ranking system or ensure that a page refresh will enhance search performance.
However, it aims to provide actionable recommendations based on evidence that will help prioritize pages for a human inspector.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
